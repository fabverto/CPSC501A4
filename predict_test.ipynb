# %% [markdown]
# Tensor Flow version setup

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# Imports that are needed

# %%
import sys
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Use this to upload the model

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d2df7dca-3dbb-4b28-8ea1-0237b0b29382" name="files[]" multiple disabled />
#      <output id="result-d2df7dca-3dbb-4b28-8ea1-0237b0b29382">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving notMNIST.h5 to notMNIST (1).h5
# Saving notMNIST.npz to notMNIST.npz

# %% [markdown]
# Google Collab will not overwrite files so you'll need to remove olds ones with command line calls

# %%
#!rm "MNIST.h5"
#!rm "notMNIST.h5"
#!rm "notMNIST.npz"

# %% [markdown]
# Determine the arguments

# %%
sys.argv = ["", input("Dataset:"), input("Model:")]
# Out:
# Dataset:notMNIST
# Model:notMNIST.h5

# %%
def check_args():
     if(len(sys.argv) != 3):
          print("Usage python predict_test.py <MNIST,notMNIST> <model.h5>")
          sys.exit(1)
     if sys.argv[1] == "MNIST":
          print("--Dataset MNIST--")
          class_names = list(range(10))
          mnist = tf.keras.datasets.mnist
          (x_train, y_train), (x_test, y_test) = mnist.load_data()
          data = (x_test, y_test)
     elif sys.argv[1] == "notMNIST":
          print("--Dataset notMNIST--")
          class_names = ["A","B","C","D","E","F","G","H","I","J"]
          with np.load("notMNIST.npz", allow_pickle=True) as f:
            x_test, y_test = f['x_test'], f['y_test']
          data = (x_test, y_test)
     else:
          print(f"Choose MNIST or notMNIST, not {sys.argv[1]}")
          sys.exit(2)
     if sys.argv[2][-3:] != ".h5":
          print(f"{sys.argv[2]} is not a h5 extension")
          sys.exit(3)
     return class_names, data

# %% [markdown]
# Completed functions to plot for you

# %%
def plot(class_names, prediction, true_label, predicted_label, img):
    plt.figure(figsize=(6,3))
    plt.subplot(1,2,1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(prediction)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],100*np.max(prediction),class_names[true_label]),color=color)
    plt.subplot(1,2,2)
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(class_names, prediction, color="#777777")
    plt.ylim([0, 1])
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# Finish this function to predict output from input

# %%
def main():
     class_names, data = check_args()
     x_test, y_test = data
     print(f"--Load Model {sys.argv[2]}--")
     #Load the model that should be in sys.argv[2]
     #model = None      <-------- Added code below
     model = tf.keras.models.load_model(sys.argv[2])
     pick = input(f"Pick test_image (0 -> {len(x_test)-1}):")
     while pick.isdigit() and int(pick) >= 0 and int(pick) < len(x_test):
        pick = int(pick)
        img = x_test[pick]
        guess = y_test[pick]
        print(f"--Should be Class {guess}--")
        predict(model, class_names, img, guess)
        pick = input(f"Pick test_image (0 -> {len(x_test)-1}):")
     print("Done")

def predict(model, class_names, img, true_label):
    img = np.array([img])
    #Replace these two lines with code to make a prediction
    #prediction = [1/10,1/10,1/10,1/10,1/10,1/10,1/10,1/10,1/10,1/10] <----------------Added code below
    prediction = model.predict(img)
    #Determine what the predicted label is
    #predicted_label = 0 <----------------------- Added code below
    predicted_label = np.argmax(prediction[0])
    plot(class_names, prediction[0], true_label, predicted_label, img[0])
    plt.show()
main()
# Out:
# --Dataset notMNIST--
# --Load Model notMNIST.h5--
# Pick test_image (0 -> 9999):1
# --Should be Class 0--
# Pick test_image (0 -> 9999):2
# --Should be Class 5--
# Pick test_image (0 -> 9999):3
# --Should be Class 9--
# Pick test_image (0 -> 9999):4
# --Should be Class 0--
# Pick test_image (0 -> 9999):5
# --Should be Class 4--
# Pick test_image (0 -> 9999):6
# --Should be Class 7--
# Pick test_image (0 -> 9999):7
# --Should be Class 2--
# Pick test_image (0 -> 9999):8
# --Should be Class 3--
# Pick test_image (0 -> 9999):9
# --Should be Class 3--
# Pick test_image (0 -> 9999):10
# --Should be Class 5--
# Pick test_image (0 -> 9999):11
# --Should be Class 4--
# Pick test_image (0 -> 9999):1
# --Should be Class 0--
# Pick test_image (0 -> 9999):12
# --Should be Class 5--
# Pick test_image (0 -> 9999):13
# --Should be Class 6--
# Pick test_image (0 -> 9999):14
# --Should be Class 1--
# Pick test_image (0 -> 9999):15
# --Should be Class 7--
# Pick test_image (0 -> 9999):16
# --Should be Class 7--
# Pick test_image (0 -> 9999):17
# --Should be Class 0--
# Pick test_image (0 -> 9999):18
# --Should be Class 7--
# Pick test_image (0 -> 9999):19
# --Should be Class 9--
# Pick test_image (0 -> 9999):20
# --Should be Class 3--
# Pick test_image (0 -> 9999):21
# --Should be Class 2--
# Pick test_image (0 -> 9999):22
# --Should be Class 8--
# Pick test_image (0 -> 9999):23
# --Should be Class 5--
# Pick test_image (0 -> 9999):24
# --Should be Class 5--
# Pick test_image (0 -> 9999):25
# --Should be Class 4--
# Pick test_image (0 -> 9999):26
# --Should be Class 7--
# Pick test_image (0 -> 9999):27
# --Should be Class 4--
# Pick test_image (0 -> 9999):28
# --Should be Class 1--
# Pick test_image (0 -> 9999):29
# --Should be Class 0--
# Pick test_image (0 -> 9999):30
# --Should be Class 4--
# Pick test_image (0 -> 9999):31
# --Should be Class 7--
# Pick test_image (0 -> 9999):32
# --Should be Class 8--
# Pick test_image (0 -> 9999):33
# --Should be Class 3--
# Pick test_image (0 -> 9999):34
# --Should be Class 4--
# Pick test_image (0 -> 9999):35
# --Should be Class 3--
# Pick test_image (0 -> 9999):36
# --Should be Class 7--
# Pick test_image (0 -> 9999):37
# --Should be Class 4--
# Pick test_image (0 -> 9999):38
# --Should be Class 0--
# Pick test_image (0 -> 9999):39
# --Should be Class 9--
# Pick test_image (0 -> 9999):40
# --Should be Class 8--
# Pick test_image (0 -> 9999):41
# --Should be Class 2--
# Pick test_image (0 -> 9999):42
# --Should be Class 0--
# Pick test_image (0 -> 9999):43
# --Should be Class 1--
# Pick test_image (0 -> 9999):44
# --Should be Class 1--
# Pick test_image (0 -> 9999):45
# --Should be Class 0--
# Pick test_image (0 -> 9999):46
# --Should be Class 8--
# Pick test_image (0 -> 9999):47
# --Should be Class 1--
# Pick test_image (0 -> 9999):48
# --Should be Class 8--
# Pick test_image (0 -> 9999):49
# --Should be Class 1--
# Pick test_image (0 -> 9999):50
# --Should be Class 7--
# Pick test_image (0 -> 9999):51
# --Should be Class 5--
# Pick test_image (0 -> 9999):52
# --Should be Class 5--
# Pick test_image (0 -> 9999):53
# --Should be Class 1--
# Pick test_image (0 -> 9999):999
# --Should be Class 2--
# Pick test_image (0 -> 9999):1000
# --Should be Class 0--
# Pick test_image (0 -> 9999):1001
# --Should be Class 2--
# Pick test_image (0 -> 9999):1002
# --Should be Class 8--
# Pick test_image (0 -> 9999):1003
# --Should be Class 5--
# Pick test_image (0 -> 9999):1004
# --Should be Class 1--
# Pick test_image (0 -> 9999):1005
# --Should be Class 8--
# Pick test_image (0 -> 9999):106
# --Should be Class 1--
# Pick test_image (0 -> 9999):1007
# --Should be Class 6--
# Pick test_image (0 -> 9999):3000
# --Should be Class 9--
# Pick test_image (0 -> 9999):4000
# --Should be Class 1--
# Pick test_image (0 -> 9999):5000
# --Should be Class 4--
# Pick test_image (0 -> 9999):6000
# --Should be Class 8--
# Pick test_image (0 -> 9999):7000
# --Should be Class 5--
# Pick test_image (0 -> 9999):8000
# --Should be Class 3--
# Pick test_image (0 -> 9999):9000
# --Should be Class 4--
# Pick test_image (0 -> 9999):9999
# --Should be Class 0--
# Pick test_image (0 -> 9999):9998
# --Should be Class 1--
# Pick test_image (0 -> 9999):9997
# --Should be Class 0--
# Pick test_image (0 -> 9999):9996
# --Should be Class 1--
